# %% [markdown]
# <a href="https://colab.research.google.com/github/odimusv/ISYS2001-A2-Budget-Buddy/blob/main/starter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏦 Project Overview
#
# Welcome to your **Smart Finance Assistant** development journey! This notebook will evolve from basic CSV processing to a complete AI-powered finance application.
#
# **Final Application Components:**
# - 💬 **AI Chat Interface** - Financial advice personality
# - 📊 **Data Analysis** - CSV transaction processing
# - 🔍 **RAG System** - Retrieval from financial documents
# - 🛠️ **Custom Tools** - Calculators and utilities
# - 🌐 **Gradio UI** - Professional web interface
#
# **Development Approach**: Build progressively from foundation to advanced features, using AI collaboration throughout.

# %% [markdown]
# ---
#
# # 🚀 Getting Started: Foundation Setup
#
# ## Initial Setup
# This cell installs the necessary libraries. In a Colab environment, you would uncomment the first line.

# %%
# Uncomment the line below when running in Google Colab
# !pip install gradio pandas hands-on-ai

# Import core libraries
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print("📦 Core libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")

# %% [markdown]
# ## Hands-on-AI Configuration
#
# Set up the hands-on-ai package for advanced features (chat, RAG, tools):

# %%
import os

# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.locollm.org'
os.environ['HANDS_ON_AI_MODEL'] = 'gemma3:4b'
os.environ['HANDS_ON_AI_API_KEY'] = 'Curtin2026ISYS20015002'

print("🔑 Hands-on-AI configured successfully!")
# Out:
# 🔑 Hands-on-AI configured successfully!

# %% [markdown]
# The API key this semester is:  **isys2001-assignment-key**

# %% [markdown]
# ## Connection Test
#
# Test that everything is working correctly:

# %%
from hands_on_ai.chat import get_response

# Test the connection to the hands-on-ai server
try:
    response = get_response("Hello! I'm building a Smart Finance Assistant.")
    print("✅ Hands-on-AI connection successful!")
    print(f"Response: {response}")
except Exception as e:
    print(f"❌ Connection issue: {e}")
    print("You can still work on the data processing foundation without this.")
# Out:
# ✅ Hands-on-AI connection successful!
# Response: That’s fantastic! A Smart Finance Assistant sounds like a really useful project. I'd love to hear more about it.
#
# To help me understand how I can best assist you, could you tell me a bit about what you're building? For example:
#
# *   **What's the primary goal of your assistant?** (e.g., budgeting, investment tracking, expense tracking, debt management, financial advice, etc.)
# *   **What platform are you building it for?** (e.g., web app, mobile app, voice assistant – Alexa, Google Assistant, etc.)
# *   **What's the core functionality you're focusing on right now?** (e.g., connecting to bank accounts, analyzing transactions, generating reports, setting goals, etc.)
# *   **What technologies are you considering using?** (e.g., Python, JavaScript, databases, APIs, etc.)
#
# ...

# %% [raw]
# ---

# %% [markdown]
# # 🏗️ Foundation: Data Processing Skills
#
# Before building advanced features, establish solid data processing foundations. This section focuses on CSV transaction analysis - the core of your finance assistant.
#
# ## Foundation Skill Checkpoint ✅
#
# **Master these basics before advancing to chat/RAG/tools:**
# - [ ] Load and clean CSV transaction data
# - [ ] Handle real-world data issues (dollar signs, missing values)
# - [ ] Calculate spending summaries by category
# - [ ] Generate business-appropriate insights
# - [ ] Format output for professional presentation
# - [ ] Test functions with various data scenarios
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration Strategy
#
# For this foundation work, use AI to:
# 1. **Generate initial code** with specific business context
# 2. **Handle data cleaning** and validation
# 3. **Create professional formatting** for outputs
# 4. **Suggest business insights** from data patterns
# 5. **Help with testing** edge cases and error handling
#
# **Remember**: You're directing AI like a junior developer - always review and improve their suggestions!
# :::
#
# ## Sample Transaction Data Setup
#
# Create or load sample transaction data to work with:

# %%
# 🤖 AI Collaboration Opportunity:
# Ask AI to help you create realistic sample transaction data
# Include Australian businesses and various spending categories

# Sample data structure for testing
sample_transactions = {
    'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04', '2024-08-05'],
    'Amount': ['$45.50', '$12.00', '$89.95', '$3.50', '-$25.00'],  # Note: includes $ signs and refund
    'Category': ['Groceries', 'Transport', 'Entertainment', 'Coffee', 'Refund'],
    'Description': ['Woolworths', 'Opal Card', 'Concert Tickets', 'Campus Cafe', 'Returned Item']
}

# Create DataFrame from sample data
df_sample = pd.DataFrame(sample_transactions)
print("📋 Sample transaction data created:")
print(df_sample)

# %% [markdown]
# ---
#
# # 📊 Six-Step Development Methodology
#
# Your notebook must demonstrate the six-step methodology with clear evidence of AI collaboration at each step.
#
# ## STEP 1: Understand the Problem
#
# **🎯 Define Your Finance Problem**
#
# In this section, clearly state your chosen finance problem in business terms.
#
# ::: {.callout-note}
# ## Problem Definition Template
#
# *Example: "I want to help people understand their spending habits by analyzing their bank transaction exports. The system should identify spending patterns, highlight potential savings opportunities, and provide actionable financial insights in easy-to-understand language."*
#
# **🤖 AI Prompt to Try:**
# ```
# "Help me brainstorm specific personal finance problems that could be solved
# with a CSV analysis tool. I'm interested in helping people with budgeting
# and spending awareness. What are common financial challenges that data
# analysis could address?"
# ```
#
# **Your Problem Statement:**
# Many students and young adults struggle to understand where their money goes. A Budget Buddy will help users upload their transaction data, summarise their spending and receive practical and useful budgeting advice.
#
# ## STEP 2: Identify Inputs and Outputs
#
# **📥 Define Your Data Flow**
#
# Clearly specify what data you'll work with and what insights you'll generate.
#
# ## Input/Output Analysis Template
#
# **Inputs:**
# - CSV file with transaction data (columns: Date, Amount, Category, Description)
# - User preferences (spending goals, categories to focus on)
# - Time period for analysis
#
# **Outputs:**
# - Total spending summary by category
# - Average spending patterns
# - Spending trend analysis
# - Actionable savings recommendations
# - Visual spending breakdown (future enhancement)
#
# **🤖 AI Prompt to Try:**
# ```
# "For a personal finance assistant that analyzes CSV transaction data,
# what are the most valuable inputs I should collect and outputs I should
# provide? Consider both technical data processing and business value
# for the user."
# ```
#
# **Your Input/Output Definition:**
#
# Inputs:
#
# * Transaction CSV
# * Date, amount, category and description for expense inputs for analysis
#
#
# Outputs:
#
# * Transaction table showing data quality and clean amounts
# * Category summary that shows total avg, count and percentage by category
# * Spending report summarises total spending and budget status
# * Budget Buddy response gives advice based on the uploaded data
#
# ## STEP 3: Work the Problem by Hand
#
# **✋ Manual Calculation Examples**
#
# Show 2-3 worked examples to understand the logic before coding.
#
#
# ## Example Business Calculation
#
# Given this sample data:
#
# | Date | Amount | Category | Description |
# |------|--------|----------|-------------|
# | 2024-08-01 | $45.50 | Groceries | Woolworths |
# | 2024-08-02 | $12.00 | Transport | Opal Card |
# | 2024-08-03 | $89.95 | Entertainment | Concert |
# | 2024-08-04 | -$15.00 | Refund | Returned item |
#
# **Manual Calculations:**
# - Total Spending: $45.50 + $12.00 + $89.95 - $15.00 = $132.45
# - By Category: Groceries $45.50, Transport $12.00, Entertainment $89.95
# - Average Transaction: $132.45 ÷ 4 = $33.11
# - Insight: Entertainment represents 67% of positive spending
#
# **🤖 AI Prompt to Try:**
# ```
# "Give me 3 realistic examples of Australian transaction data with different
# scenarios (normal spending, refunds, large purchases). Show me how to manually
# calculate meaningful financial insights from each scenario."
# ```
#
# **Your Manual Examples:**
#
# Manual calculation 1 – Positive spending total
# Only positive amounts count as spending.
#
# [ 45.50 + 12.00 + 89.95 + 3.50 = 150.95 ]
#
# Positive spending total = $150.95
#
# Manual calculation 2 – Net spending after refund
# The refund/credit reduces the net total, but Budget Buddy should still track it separately.
#
# [ 150.95 - 25.00 = 125.95 ]
#
# Net spending = $125.95
# Refunds/credits = $25.00
# ## STEP 4: Write Pseudocode
#
# **📝 Plan Your Solution Logic**
#
# Sketch the algorithm in plain English before coding.
#
#
# ## Pseudocode Template
#
# ```
# FUNCTION analyze_spending_data(csv_file):
#     // Step 1: Load and validate data
#     - Read CSV file into DataFrame
#     - Check for required columns (Date, Amount, Category, Description)
#     - Handle missing or invalid data
#
#     // Step 2: Clean financial data
#     - Remove dollar signs from Amount column
#     - Convert to numeric values
#     - Separate positive spending from refunds
#
#     // Step 3: Calculate business metrics
#     - Group transactions by category
#     - Calculate totals, averages, counts per category
#     - Identify spending patterns and outliers
#
#     // Step 4: Generate insights
#     - Calculate percentages of total spending
#     - Identify top spending categories
#     - Suggest potential savings opportunities
#
#     // Step 5: Format for presentation
#     - Create business-friendly output
#     - Include currency formatting
#     - Add explanatory text for insights
#
#     RETURN formatted_analysis
# ```
#
# **🤖 AI Prompt to Try:**
# ```
# "Review my pseudocode for analyzing spending data from a CSV. Are there any
# edge cases I'm missing? What business logic should I add to make this more
# valuable for personal finance insights?"
# ```
#
#
# **Your Pseudocode:**
#
# FUNCTION BudgetBuddy(csv_file, monthly_budget, user_question):
#
#     LOAD csv_file into a table
#
#     CHECK the table has Date, Amount, Category, Description
#     IF required columns are missing:
#         RETURN a helpful error message
#
#     CLEAN the data:
#         convert Date into real dates
#         remove "$", commas and spaces from Amount
#         convert Amount into numbers
#         drop rows where Date or Amount cannot be cleaned
#         label each row as Spending, Refund/Credit, or Zero/No spend
#
#     ANALYSE spending:
#         keep positive Amount values for spending totals
#         keep negative Amount values for refunds
#         calculate total positive spending
#         calculate total refunds
#         calculate net spending
#         group positive spending by Category
#         calculate total, average, count and percentage for each Category
#         identify the biggest spending Category
#         compare total spending to monthly_budget if one is entered
#
#     GENERATE advice:
#         explain the top spending category
#         warn if the user is over budget
#         suggest one practical saving action
#         mention refunds separately so they do not hide real habits
#
#     CHAT/RAG:
#         use the spending summary as context for Budget Buddy chat
#         retrieve relevant budgeting guide notes for finance questions
#         combine retrieved notes with the user's transaction summary
#
#     TOOL:
#         calculate months needed for a savings goal
#
#     DISPLAY:
#         show report, category table, cleaned table, chat, RAG answer and tool output in Gradio
#
# ## STEP 5: Convert to Python
#
# **💻 Implementation with AI Collaboration**
#
# Now implement your solution using AI assistance. Focus on creating professional, business-appropriate code.
#
#
# ## 🤖 Implementation Strategy
#
# **Effective AI Prompts for Implementation:**
# ```
# "I'm implementing a Smart Finance Assistant. Based on my pseudocode, please create
# a Python function that [specific functionality]. The code should:
# - Handle real-world CSV data issues (dollar signs, missing values)
# - Include clear comments explaining business logic
# - Use professional variable names
# - Format output for business presentation
# - Include basic error handling"
# ```
#
# **Remember to critique and improve AI responses before using them!**
# :::
#
# ### Foundation Data Processing Functions

# %%
# 🤖 AI Collaboration: Data Loading and Cleaning Function
# Ask AI to help you create a robust data loading function

def load_and_clean_transaction_data(file_path):
    """
    Load and clean transaction data for the Smart Finance Assistant

    🤖 AI Collaboration Prompt:
    "Create a function to load CSV transaction data with Date, Amount, Category,
    Description columns. Handle dollar signs in Amount, missing values, and
    data validation. Include clear business-focused error messages."

    Args:
        file_path: Path to CSV file, file object, or pandas DataFrame
    Returns:
        pandas.DataFrame: Cleaned transaction data
    """
    import os
    import pandas as pd
    import numpy as np
    from pandas.errors import EmptyDataError

    if file_path is None:
        raise ValueError("Please provide a transaction CSV file or a pandas DataFrame.")

    try:
        if isinstance(file_path, pd.DataFrame):
            df = file_path.copy()
        else:
            csv_source = (
                file_path.name
                if hasattr(file_path, "name") and not isinstance(file_path, (str, bytes, os.PathLike))
                else file_path
            )
            df = pd.read_csv(csv_source)
    except EmptyDataError:
        raise ValueError(
            "The transaction file is empty. Please upload a CSV with Date, Amount, Category and Description columns."
        )
    except FileNotFoundError:
        raise ValueError(
            "The transaction file could not be found. Please check the file path or upload the CSV again."
        )
    except Exception as e:
        raise ValueError(
            f"Unable to load the transaction CSV. Please check the file format. Details: {e}"
        )

    if df.empty:
        raise ValueError("The transaction file has no rows to analyse.")

    df.columns = [str(col).strip() for col in df.columns]

    required_columns = ["Date", "Amount", "Category", "Description"]
    column_lookup = {str(col).strip().lower(): col for col in df.columns}
    missing_columns = [col for col in required_columns if col.lower() not in column_lookup]

    if missing_columns:
        raise ValueError(
            "Missing required transaction column(s): "
            + ", ".join(missing_columns)
            + ". The CSV must include Date, Amount, Category and Description."
        )

    df = df[[column_lookup[col.lower()] for col in required_columns]].copy()
    df.columns = required_columns
    df = df.dropna(how="all")

    if df.empty:
        raise ValueError("The transaction file only contains blank rows.")

    df["Category"] = df["Category"].fillna("Uncategorised").astype(str).str.strip()
    df.loc[df["Category"].isin(["", "nan", "None", "NaN"]), "Category"] = "Uncategorised"

    df["Description"] = df["Description"].fillna("No description provided").astype(str).str.strip()
    df.loc[df["Description"].isin(["", "nan", "None", "NaN"]), "Description"] = "No description provided"

    cleaned_amount = (
        df["Amount"]
        .astype(str)
        .str.strip()
        .str.replace("−", "-", regex=False)
        .str.replace(r"[\$,]", "", regex=True)
        .str.replace(r"^\((.*)\)$", r"-\1", regex=True)
    )
    cleaned_amount = cleaned_amount.replace(["", "nan", "NaN", "None", "none"], pd.NA)

    df["Amount"] = pd.to_numeric(cleaned_amount, errors="coerce")

    invalid_amounts = df["Amount"].isna()
    if invalid_amounts.any():
        bad_rows = (df.index[invalid_amounts] + 2).astype(str).tolist()
        raise ValueError(
            "Some transaction amounts could not be read as numbers. "
            f"Please check CSV row(s): {', '.join(bad_rows[:5])}."
        )

    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

    invalid_dates = df["Date"].isna()
    if invalid_dates.any():
        bad_rows = (df.index[invalid_dates] + 2).astype(str).tolist()
        raise ValueError(
            "Some transaction dates could not be read. "
            f"Please check CSV row(s): {', '.join(bad_rows[:5])} and use a format like YYYY-MM-DD."
        )

    df = df.sort_values("Date").reset_index(drop=True)

    df["Transaction_Type"] = np.select(
        [df["Amount"] > 0, df["Amount"] < 0],
        ["Expense", "Refund"],
        default="Zero"
    )

    df["Month"] = df["Date"].dt.to_period("M").astype(str)

    return df

# Test your function
clean_data = load_and_clean_transaction_data(df_sample)
print(clean_data)

# %%
# 🤖 AI Collaboration: Spending Analysis Function
# Ask AI to help you create comprehensive spending analysis

def analyze_spending_patterns(df):
    """
    Analyze spending patterns and generate business insights

    🤖 AI Collaboration Prompt:
    "Create a function that analyzes spending by category, calculates percentages,
    identifies top spending areas, and generates actionable financial insights
    formatted for business presentation."

    Args:
        df: Cleaned transaction DataFrame
    Returns:
        dict: Analysis results and insights
    """
    import pandas as pd

    if not isinstance(df, pd.DataFrame):
        raise ValueError(
            "Spending analysis needs a pandas DataFrame created by load_and_clean_transaction_data()."
        )

    required_columns = {"Date", "Amount", "Category", "Description"}
    missing_columns = required_columns - set(df.columns)

    if missing_columns:
        raise ValueError(
            f"Cannot analyse spending because these columns are missing: {', '.join(sorted(missing_columns))}."
        )

    if df.empty:
        raise ValueError("There are no transactions to analyse.")

    working_df = df.copy()
    working_df["Amount"] = pd.to_numeric(working_df["Amount"], errors="coerce")

    if working_df["Amount"].isna().any():
        raise ValueError("The Amount column contains invalid values. Please clean the data before analysis.")

    working_df["Date"] = pd.to_datetime(working_df["Date"], errors="coerce")

    if working_df["Date"].isna().any():
        raise ValueError("The Date column contains invalid values. Please clean the data before analysis.")

    expenses = working_df[working_df["Amount"] > 0].copy()
    refunds = working_df[working_df["Amount"] < 0].copy()

    total_spending = float(expenses["Amount"].sum())
    total_refunds = float(abs(refunds["Amount"].sum()))
    net_spending = float(working_df["Amount"].sum())

    if total_spending > 0:
        category_summary = (
            expenses.groupby("Category", as_index=False)
            .agg(
                TotalSpent=("Amount", "sum"),
                TransactionCount=("Amount", "count"),
                AverageTransaction=("Amount", "mean")
            )
            .sort_values("TotalSpent", ascending=False)
            .reset_index(drop=True)
        )

        category_summary["Percentage"] = (category_summary["TotalSpent"] / total_spending * 100).round(2)
        category_summary["TotalSpent"] = category_summary["TotalSpent"].round(2)
        category_summary["AverageTransaction"] = category_summary["AverageTransaction"].round(2)
        category_summary["FormattedTotal"] = category_summary["TotalSpent"].map(lambda value: f"${value:,.2f}")

        top_row = category_summary.iloc[0]
        top_category = str(top_row["Category"])
        top_category_amount = float(top_row["TotalSpent"])
        top_category_percentage = float(top_row["Percentage"])

        largest_row = expenses.sort_values("Amount", ascending=False).iloc[0]
        largest_transaction = {
            "Date": largest_row["Date"].strftime("%Y-%m-%d"),
            "Amount": float(largest_row["Amount"]),
            "Category": str(largest_row["Category"]),
            "Description": str(largest_row["Description"])
        }
    else:
        category_summary = pd.DataFrame(
            columns=[
                "Category",
                "TotalSpent",
                "TransactionCount",
                "AverageTransaction",
                "Percentage",
                "FormattedTotal"
            ]
        )
        top_category = None
        top_category_amount = 0.0
        top_category_percentage = 0.0
        largest_transaction = None

    discretionary_categories = [
        "Coffee",
        "Dining",
        "Entertainment",
        "Shopping",
        "Takeaway",
        "Restaurants",
        "Subscriptions"
    ]

    discretionary_spending = float(
        expenses[expenses["Category"].isin(discretionary_categories)]["Amount"].sum()
    )

    discretionary_percentage = (
        discretionary_spending / total_spending * 100
        if total_spending > 0
        else 0.0
    )

    refund_summary = (
        refunds.assign(RefundAmount=refunds["Amount"].abs())
        .groupby("Category", as_index=False)
        .agg(
            TotalRefunds=("RefundAmount", "sum"),
            RefundCount=("RefundAmount", "count")
        )
        .sort_values("TotalRefunds", ascending=False)
        .reset_index(drop=True)
        if not refunds.empty
        else pd.DataFrame(columns=["Category", "TotalRefunds", "RefundCount"])
    )

    date_start = working_df["Date"].min()
    date_end = working_df["Date"].max()
    days_covered = max((date_end - date_start).days + 1, 1)

    business_insights = []

    if total_spending == 0:
        business_insights.append(
            "No positive spending transactions were found; the data appears to contain only refunds or zero-value transactions."
        )
    else:
        business_insights.append(
            f"Your largest spending category is {top_category}, accounting for "
            f"${top_category_amount:,.2f} ({top_category_percentage:.1f}% of spending)."
        )

        if top_category_percentage >= 35:
            business_insights.append(
                f"{top_category} is a major budget driver. A 10% reduction in this category "
                f"could save about ${top_category_amount * 0.10:,.2f} over this period."
            )

        if discretionary_percentage >= 40:
            business_insights.append(
                f"Flexible lifestyle categories such as coffee, dining and entertainment make up "
                f"{discretionary_percentage:.1f}% of spending, so small habit changes could have a noticeable impact."
            )

        coffee_total = (
            float(category_summary.loc[category_summary["Category"].eq("Coffee"), "TotalSpent"].sum())
            if not category_summary.empty
            else 0.0
        )

        if coffee_total > 0:
            business_insights.append(
                f"Coffee spending totals ${coffee_total:,.2f}. "
                "Setting a weekly coffee cap is a simple student-friendly savings action."
            )

        daily_average = total_spending / days_covered
        business_insights.append(
            f"Average daily spending across the period is ${daily_average:,.2f}, "
            f"based on {days_covered} day(s) of transactions."
        )

    if total_refunds > 0:
        business_insights.append(
            f"Refunds total ${total_refunds:,.2f}. "
            "They are tracked separately so they do not hide your real spending habits."
        )

    return {
        "total_spending": round(total_spending, 2),
        "total_refunds": round(total_refunds, 2),
        "net_spending": round(net_spending, 2),
        "transaction_count": int(len(working_df)),
        "expense_transaction_count": int(len(expenses)),
        "refund_transaction_count": int(len(refunds)),
        "average_expense": round(float(expenses["Amount"].mean()), 2) if not expenses.empty else 0.0,
        "category_count": int(expenses["Category"].nunique()) if not expenses.empty else 0,
        "category_summary": category_summary,
        "category_totals": {
            row["Category"]: float(row["TotalSpent"])
            for _, row in category_summary.iterrows()
        },
        "refund_summary": refund_summary,
        "top_category": top_category,
        "top_category_amount": round(top_category_amount, 2),
        "top_category_percentage": round(top_category_percentage, 2),
        "largest_transaction": largest_transaction,
        "discretionary_spending": round(discretionary_spending, 2),
        "discretionary_percentage": round(discretionary_percentage, 2),
        "date_range": {
            "start": date_start.strftime("%Y-%m-%d"),
            "end": date_end.strftime("%Y-%m-%d"),
            "days": int(days_covered)
        },
        "business_insights": business_insights
    }

# Test your function
# Test your function
analysis = analyze_spending_patterns(clean_data)

print("SPENDING ANALYSIS SUMMARY")
print("-" * 50)
print(f"Total Spending: ${analysis['total_spending']:.2f}")
print(f"Total Refunds: ${analysis['total_refunds']:.2f}")
print(f"Net Spending: ${analysis['net_spending']:.2f}")
print(f"Total Transactions: {analysis['transaction_count']}")
print(f"Expense Transactions: {analysis['expense_transaction_count']}")
print(f"Refund Transactions: {analysis['refund_transaction_count']}")
print(f"Average Expense: ${analysis['average_expense']:.2f}")

print("\nCATEGORY BREAKDOWN")
print("-" * 50)
display(analysis["category_summary"])

print("\nREFUND SUMMARY")
print("-" * 50)

if not analysis["refund_summary"].empty:
    display(analysis["refund_summary"])
else:
    print("No refunds found.")

print("\nTOP SPENDING CATEGORY")
print("-" * 50)
print(f"Category: {analysis['top_category']}")
print(f"Amount: ${analysis['top_category_amount']:.2f}")
print(f"Percentage: {analysis['top_category_percentage']:.2f}%")

print("\nLARGEST TRANSACTION")
print("-" * 50)

largest = analysis["largest_transaction"]

if largest is not None:
    print(f"Date: {largest['Date']}")
    print(f"Description: {largest['Description']}")
    print(f"Category: {largest['Category']}")
    print(f"Amount: ${largest['Amount']:.2f}")
else:
    print("No expense transactions found.")

print("\nBUSINESS INSIGHTS")
print("-" * 50)

for insight in analysis["business_insights"]:
    print(f"- {insight}")

# %%
# 🤖 AI Collaboration: Business Insights Generator
# Ask AI to help create professional financial recommendations

def generate_financial_recommendations(analysis_data):
    """
    Generate actionable financial recommendations based on spending analysis

    🤖 AI Collaboration Prompt:
    "Based on spending analysis data, create professional financial
    recommendations. Include specific savings opportunities, spending
    pattern observations, and actionable advice formatted for a
    personal finance app user."

    Args:
        analysis_data: Dictionary with spending analysis results
    Returns:
        str: Formatted recommendations report
    """
    import pandas as pd

    if not isinstance(analysis_data, dict):
        raise ValueError("Recommendations need the dictionary returned by analyze_spending_patterns().")

    total_spending = float(analysis_data.get("total_spending", 0) or 0)
    total_refunds = float(analysis_data.get("total_refunds", 0) or 0)
    net_spending = float(analysis_data.get("net_spending", 0) or 0)

    top_category = analysis_data.get("top_category")
    top_amount = float(analysis_data.get("top_category_amount", 0) or 0)
    top_percentage = float(analysis_data.get("top_category_percentage", 0) or 0)

    date_range = analysis_data.get("date_range", {})
    insights = analysis_data.get("business_insights", [])

    category_summary = analysis_data.get("category_summary", pd.DataFrame())

    if isinstance(category_summary, list):
        category_summary = pd.DataFrame(category_summary)
    elif isinstance(category_summary, dict):
        category_summary = pd.DataFrame(category_summary)
    elif category_summary is None:
        category_summary = pd.DataFrame()

    lines = []
    lines.append("## 💡 Budget Buddy Financial Recommendations")
    lines.append("")
    lines.append(f"**Period analysed:** {date_range.get('start', 'N/A')} to {date_range.get('end', 'N/A')}")
    lines.append(f"**Total spending:** ${total_spending:,.2f}")
    lines.append(f"**Refunds tracked separately:** ${total_refunds:,.2f}")
    lines.append(f"**Net cash impact:** ${net_spending:,.2f}")
    lines.append("")

    if total_spending <= 0:
        lines.append("### Summary")
        lines.append(
            "No positive spending transactions were found, so there is not enough spending data "
            "to make category-based recommendations."
        )
        lines.append("Add a normal month of transaction data to receive more useful budgeting guidance.")
        return "\n".join(lines)

    lines.append("### Key observations")

    if top_category:
        lines.append(
            f"- Your biggest spending area is **{top_category}** at **${top_amount:,.2f}**, "
            f"which is **{top_percentage:.1f}%** of all spending."
        )

    for insight in insights[:4]:
        lines.append(f"- {insight}")

    lines.append("")
    lines.append("### Action plan")

    if not category_summary.empty and {"Category", "TotalSpent", "Percentage"}.issubset(category_summary.columns):
        top_categories = category_summary.head(3)

        for _, row in top_categories.iterrows():
            category = str(row["Category"])
            amount = float(row["TotalSpent"])
            percentage = float(row["Percentage"])
            potential_saving = amount * 0.10

            if category.lower() == "coffee":
                action = (
                    "try a weekly coffee limit, bring coffee from home on two days, "
                    "or use campus loyalty deals"
                )
            elif category.lower() in ["dining", "restaurants", "takeaway"]:
                action = "plan two low-cost meals before buying takeaway and set a weekly eating-out cap"
            elif category.lower() == "entertainment":
                action = (
                    "choose one paid activity per week and mix in free events, "
                    "student discounts, or streaming nights"
                )
            elif category.lower() == "groceries":
                action = "shop with a list, compare unit prices, and plan meals around specials before buying"
            elif category.lower() == "transport":
                action = "compare public transport, walking, car-pooling, and ride-share costs before each trip"
            elif category.lower() == "utilities":
                action = "review usage and compare plans before the next billing cycle"
            else:
                action = "set a clear spending cap and review this category weekly"

            lines.append(
                f"- **{category}:** You spent ${amount:,.2f} ({percentage:.1f}%). "
                f"To save about ${potential_saving:,.2f}, {action}."
            )

    discretionary_percentage = float(analysis_data.get("discretionary_percentage", 0) or 0)
    discretionary_spending = float(analysis_data.get("discretionary_spending", 0) or 0)

    if discretionary_spending > 0:
        lines.append(
            f"- **Flexible spending check:** Coffee, dining and entertainment-style categories total "
            f"${discretionary_spending:,.2f} ({discretionary_percentage:.1f}%). "
            "Start with a small 5-10% reduction rather than cutting everything at once."
        )

    if total_refunds > 0:
        lines.append(
            f"- **Refund note:** You received ${total_refunds:,.2f} in refunds. "
            "Keep recording refunds separately so your budget reflects both spending behaviour and money returned."
        )

    lines.append("")
    lines.append("### Next step")
    lines.append(
        "Choose one category to improve this week, set a realistic dollar cap, "
        "and compare your next transaction export against this report."
    )
    lines.append("")
    lines.append("_This is budgeting education, not personal financial advice._")

    return "\n".join(lines)

# Test your function
recommendations = generate_financial_recommendations(analysis)
print(recommendations)

# %% [markdown]
# ---
#
# # 🌐 Advanced Features: Integrating AI Components
#
# Once your foundation data processing is solid, integrate advanced AI features using hands-on-ai.
#
# ## Chat Interface Integration

# %%
# 🤖 AI Collaboration: Financial Advice Chatbot
# Ask AI to help you create a finance-focused chat personality

from hands_on_ai import chat

def create_finance_chat_personality():
    """
    Set up a financial advisor chat personality using hands-on-ai

    🤖 AI Collaboration Prompt:
    "Help me create a system prompt for a friendly, professional financial
    advisor chatbot that can provide spending advice based on transaction
    analysis. The personality should be encouraging but practical."
    """
    system_prompt = """
You are Budget Buddy, a friendly and practical personal finance assistant for students and young adults in Australia.

Your role:
- Explain spending patterns in simple, supportive language.
- Give realistic budgeting suggestions based on transaction analysis.
- Focus on habits, category limits, savings goals and small achievable changes.
- Be encouraging, non-judgemental and specific.
- Do not pretend to be a licensed financial adviser.
- For serious debt, tax, investing or hardship issues, suggest speaking with a qualified professional or trusted support service.
- Keep responses concise, action-focused and easy to follow.
"""

    def finance_advisor(user_message, analysis_summary=None):
        if user_message is None or not str(user_message).strip():
            return "Ask me a budgeting question, such as how to reduce coffee, dining or entertainment spending."

        context_text = ""

        if analysis_summary:
            context_text = f"\n\nTransaction analysis context:\n{analysis_summary}"

        user_prompt = f"{str(user_message).strip()}{context_text}"

        try:
            if hasattr(chat, "get_response"):
                return chat.get_response(user_prompt, system=system_prompt)
            else:
                from hands_on_ai.chat import get_response
                return get_response(user_prompt, system=system_prompt)
        except Exception as e:
            return (
                "⚠️ Budget Buddy is having trouble connecting to the AI service right now. "
                "A practical fallback: pick your highest flexible spending category, set a weekly dollar cap, "
                "and review your transactions again after seven days. "
                f"Connection detail: {e}"
            )

    chat.say = finance_advisor
    chat.finance_advisor = finance_advisor
    chat.finance_system_prompt = system_prompt

    print("✅ Finance chatbot personality created. Use chat.say('your question') to test it.")
    return finance_advisor

# Test your chatbot
finance_bot = create_finance_chat_personality()
response = chat.say("I spend too much on porn, what should I do?")
print(response)
# Out:
# ✅ Finance chatbot personality created. Use chat.say('your question') to test it.
# Okay, let's tackle this! It's super common to have a little treat we love, and boba is definitely a popular one.
#
# It sounds like you're noticing a pattern – that’s the first step to changing it!
#
# **Here's what we can do:**
#
# 1. **Track it for a week:** Really write down *every* boba purchase. This will show you exactly how much you're spending each week.
# 2. **Set a realistic limit:** Based on what you’ve tracked, let’s aim for no more than $X per week (let's start with $5 – you can adjust!).
# 3. **Find cheaper alternatives:**  Could you switch to a cheaper iced drink sometimes? Or make boba at home (it’s easier than you think!).
# 4. **Reward yourself differently:** Instead of boba after a good week, maybe treat yourself to a movie or a small purchase you've been wanting.
#
# ...

# %% [markdown]
# ## RAG System for Financial Documents

# %%
# 🤖 AI Collaboration: Document Retrieval Setup
# Ask AI to help you set up RAG for financial documents

from hands_on_ai import rag

def setup_financial_rag():
    """
    Set up RAG system for financial documents and transaction data.

    This version fixes the messy output by:
    - treating keyword retrieval as a normal fallback, not an error
    - returning clean Markdown answers
    - avoiding giant raw text dumps
    - showing matched sources clearly
    """
    import os
    import textwrap
    import re
    import pandas as pd

    knowledge_dir = "financial_knowledge_base"
    os.makedirs(knowledge_dir, exist_ok=True)

    documents = {
        "budgeting_basics.txt": """
Budgeting basics for students and young adults:
A simple budget compares income with spending. Start by separating needs, wants and savings.
Needs include groceries, transport, rent and utilities. Wants include entertainment, takeaway,
subscriptions and impulse purchases. A realistic budget should leave room for some fun spending,
but it should also include a savings goal and an emergency buffer. Review transactions weekly,
not just at the end of the month.
""",
        "spending_categories.txt": """
Common spending category guidance:
Groceries can often be reduced with meal planning, shopping lists and unit-price comparison.
Coffee and dining are flexible categories where small changes add up quickly.
Entertainment should have a planned weekly or monthly cap.
Transport costs can be managed by comparing public transport, walking, cycling, car-pooling and ride-share options.
Utilities should be reviewed each billing cycle by checking usage and comparing plans.
""",
        "savings_strategy.txt": """
Savings strategy:
Choose one clear target amount and one monthly contribution.
Automate transfers where possible, even if the amount is small.
For short-term goals, track progress weekly. For longer goals, review monthly.
A good savings plan is realistic enough to continue while still allowing essential spending.
If spending is higher than expected, reduce one flexible category by 5 to 10 percent first.
"""
    }

    # Add the current transaction summary only if analysis data exists
    if "analysis" in globals() and isinstance(globals()["analysis"], dict):
        current_analysis = globals()["analysis"]

        insight_lines = current_analysis.get("business_insights", [])
        insight_text = "\n".join([f"- {insight}" for insight in insight_lines])

        documents["latest_transaction_summary.txt"] = f"""
Latest transaction summary:
Total spending: ${current_analysis.get('total_spending', 0):,.2f}
Refunds: ${current_analysis.get('total_refunds', 0):,.2f}
Net spending: ${current_analysis.get('net_spending', 0):,.2f}
Top category: {current_analysis.get('top_category', 'Unknown')}

Key insights:
{insight_text}
"""
    elif "clean_data" in globals() and isinstance(globals()["clean_data"], pd.DataFrame):
        temp_analysis = analyze_spending_patterns(globals()["clean_data"])

        insight_lines = temp_analysis.get("business_insights", [])
        insight_text = "\n".join([f"- {insight}" for insight in insight_lines])

        documents["latest_transaction_summary.txt"] = f"""
Latest transaction summary:
Total spending: ${temp_analysis.get('total_spending', 0):,.2f}
Refunds: ${temp_analysis.get('total_refunds', 0):,.2f}
Net spending: ${temp_analysis.get('net_spending', 0):,.2f}
Top category: {temp_analysis.get('top_category', 'Unknown')}

Key insights:
{insight_text}
"""

    # Save documents into the knowledge base folder
    for filename, content in documents.items():
        with open(os.path.join(knowledge_dir, filename), "w", encoding="utf-8") as file:
            file.write(textwrap.dedent(content).strip())

    def fallback_financial_search(question):
        """
        Clean keyword-based retrieval fallback.

        Instead of returning one messy raw paragraph, this function:
        - scores documents by keyword relevance
        - formats the answer as Markdown
        - gives short practical recommendations
        - lists sources clearly
        """
        if question is None or not str(question).strip():
            return "Please ask a question about budgeting, spending categories, savings, refunds or transaction patterns."

        question_text = str(question).lower()

        stop_words = {
            "what", "when", "where", "which", "with", "about", "should", "could",
            "would", "there", "their", "have", "does", "this", "that", "from",
            "your", "you", "for", "the", "and", "are", "how", "why", "can",
            "good", "best", "into", "over", "under", "because"
        }

        question_words = [
            word
            for word in re.findall(r"[a-zA-Z]+", question_text)
            if len(word) >= 4 and word not in stop_words
        ]

        scored_matches = []

        for filename, content in documents.items():
            clean_content = " ".join(textwrap.dedent(content).strip().split())
            content_lower = clean_content.lower()

            score = 0

            for word in question_words:
                if word in content_lower:
                    score += content_lower.count(word)

            # Extra boosts for common finance topics
            if "entertainment" in question_text and "entertainment" in content_lower:
                score += 5
            if "coffee" in question_text and "coffee" in content_lower:
                score += 5
            if "groceries" in question_text and "groceries" in content_lower:
                score += 5
            if "saving" in question_text or "savings" in question_text:
                if "savings" in content_lower or "saving" in content_lower:
                    score += 5
            if "refund" in question_text and "refund" in content_lower:
                score += 5
            if "budget" in question_text and "budget" in content_lower:
                score += 5

            if score > 0:
                scored_matches.append((score, filename, clean_content))

        if not scored_matches:
            return (
                "## Budget Buddy Answer\n\n"
                "I could not find a strong document match for that question.\n\n"
                "Try asking about one of these topics:\n"
                "- budgeting basics\n"
                "- entertainment spending\n"
                "- coffee or dining habits\n"
                "- groceries\n"
                "- transport\n"
                "- savings goals\n"
                "- refunds and net spending"
            )

        scored_matches.sort(reverse=True)
        top_matches = scored_matches[:2]

        answer_lines = []
        answer_lines.append("## Budget Buddy Answer")
        answer_lines.append("")

        # Use the best matching document to generate a clean response
        best_score, best_file, best_text = top_matches[0]

        if best_file == "latest_transaction_summary.txt":
            answer_lines.append("Based on your latest transaction summary:")
            answer_lines.append("")

            if "Top category:" in best_text:
                top_category_match = re.search(r"Top category:\s*([A-Za-z ]+)", best_text)
                if top_category_match:
                    answer_lines.append(f"- Your main spending focus is **{top_category_match.group(1).strip()}**.")

            total_match = re.search(r"Total spending:\s*\$([0-9,.]+)", best_text)
            refund_match = re.search(r"Refunds:\s*\$([0-9,.]+)", best_text)
            net_match = re.search(r"Net spending:\s*\$([0-9,.]+)", best_text)

            if total_match:
                answer_lines.append(f"- Total spending reviewed: **${total_match.group(1)}**.")
            if refund_match:
                answer_lines.append(f"- Refunds tracked separately: **${refund_match.group(1)}**.")
            if net_match:
                answer_lines.append(f"- Net spending impact: **${net_match.group(1)}**.")

            answer_lines.append("")
            answer_lines.append("### Practical recommendation")
            answer_lines.append(
                "Start with the category taking the biggest share of spending. "
                "Set a small weekly cap first instead of trying to cut everything at once."
            )
            answer_lines.append(
                "A realistic first target is a **5-10% reduction** in that category for the next week."
            )

        elif "spending_categories" in best_file:
            answer_lines.append("For spending categories, the best approach is to separate essential and flexible spending.")
            answer_lines.append("")
            answer_lines.append("- **Flexible categories** like coffee, dining and entertainment are usually the easiest to reduce.")
            answer_lines.append("- **Essential categories** like groceries, transport and utilities should be optimised rather than removed.")
            answer_lines.append("- Pick one category, set a weekly cap, then compare your next CSV export against that cap.")

        elif "savings_strategy" in best_file:
            answer_lines.append("For savings goals, use a simple target-based approach.")
            answer_lines.append("")
            answer_lines.append("- Choose a clear target amount.")
            answer_lines.append("- Decide how much you can contribute each month.")
            answer_lines.append("- Automate the transfer after income arrives.")
            answer_lines.append("- If spending is too high, reduce one flexible category by 5-10% first.")

        elif "budgeting_basics" in best_file:
            answer_lines.append("A strong budget starts by separating needs, wants and savings.")
            answer_lines.append("")
            answer_lines.append("- Track essential costs first: groceries, transport, rent and utilities.")
            answer_lines.append("- Then review flexible spending: coffee, dining, entertainment and subscriptions.")
            answer_lines.append("- Review transactions weekly so your budget is based on real behaviour.")

        else:
            answer_lines.append(best_text[:500] + "...")

        answer_lines.append("")
        answer_lines.append("### Sources used")
        for _, filename, _ in top_matches:
            answer_lines.append(f"- `{filename}`")

        return "\n".join(answer_lines)

    try:
        from hands_on_ai.rag import index_documents, query_documents

        index_path = index_documents(knowledge_dir, output_file="financial_knowledge_index.npz")

        def ask_financial_documents(question):
            if question is None or not str(question).strip():
                return "Please ask a question about budgeting, spending categories or savings strategies."

            try:
                result = query_documents(str(question), index_path=index_path)

                if result is None or not str(result).strip():
                    return fallback_financial_search(question)

                return (
                    "## Budget Buddy Answer\n\n"
                    f"{result}\n\n"
                    "### Source\n"
                    "- Financial knowledge index"
                )

            except Exception:
                return fallback_financial_search(question)

        rag.ask = ask_financial_documents
        rag.finance_knowledge_dir = knowledge_dir
        rag.finance_index_path = index_path

        print("✅ Financial document retrieval is ready using indexed RAG.")

        return {
            "knowledge_dir": knowledge_dir,
            "index_path": index_path,
            "documents": list(documents.keys()),
            "ask": ask_financial_documents,
            "mode": "indexed_rag"
        }

    except Exception:
        rag.ask = fallback_financial_search
        rag.finance_knowledge_dir = knowledge_dir
        rag.finance_index_path = None

        print("✅ Financial document retrieval is ready using keyword search mode.")

        return {
            "knowledge_dir": knowledge_dir,
            "index_path": None,
            "documents": list(documents.keys()),
            "ask": fallback_financial_search,
            "mode": "keyword_search"
        }

# Test your RAG system
rag_config = setup_financial_rag()
answer = rag.ask("What's a good budgeting strategy for someone who overspends on entertainment?")
print(answer)
# Out:
# ✅ Financial document retrieval is ready using keyword search mode.
# ## Budget Buddy Answer
#
# Based on your latest transaction summary:
#
# - Your main spending focus is **Entertainment Key insights**.
# - Total spending reviewed: **$150.95**.
# - Refunds tracked separately: **$25.00**.
# - Net spending impact: **$125.95**.
#
# ### Practical recommendation
# Start with the category taking the biggest share of spending. Set a small weekly cap first instead of trying to cut everything at once.
# A realistic first target is a **5-10% reduction** in that category for the next week.
#
# ### Sources used
# - `latest_transaction_summary.txt`
# - `budgeting_basics.txt`

# %% [markdown]
# ## Custom Financial Tools

# %%
# 🤖 AI Collaboration: Custom Tool Development
# Ask AI to help you create useful financial calculators

from hands_on_ai import agent

def create_savings_calculator_tool():
    """
    Create a custom savings goal calculator as an agent tool

    🤖 AI Collaboration Prompt:
    "Create a savings goal calculator function that takes current savings,
    monthly contribution, and target amount, then calculates time to reach
    goal. Format output for user-friendly display."
    """
    import math
    import pandas as pd

    def savings_calculator(current_savings, monthly_contribution, target_amount):
        raw_values = {
            "current savings": current_savings,
            "monthly contribution": monthly_contribution,
            "target amount": target_amount
        }

        parsed_values = {}

        for label, value in raw_values.items():
            try:
                parsed_values[label] = float(str(value).replace("$", "").replace(",", "").strip())
            except Exception:
                return f"⚠️ The {label} must be a valid number."

        current = parsed_values["current savings"]
        monthly = parsed_values["monthly contribution"]
        target = parsed_values["target amount"]

        if current < 0:
            return "⚠️ Current savings cannot be negative."

        if target <= 0:
            return "⚠️ Target amount must be greater than $0."

        if monthly < 0:
            return "⚠️ Monthly contribution cannot be negative."

        remaining = target - current

        if remaining <= 0:
            return (
                f"🎉 Goal already reached! You have ${current:,.2f}, which meets or exceeds "
                f"your ${target:,.2f} target."
            )

        if monthly == 0:
            return (
                f"⚠️ You still need ${remaining:,.2f}. Add a monthly contribution greater than $0 "
                "to calculate a finish date."
            )

        months_needed = int(math.ceil(remaining / monthly))
        years = months_needed // 12
        extra_months = months_needed % 12

        target_date = (
            pd.Timestamp.today() + pd.DateOffset(months=months_needed)
        ).strftime("%B %Y")

        if years and extra_months:
            time_text = f"{years} year(s) and {extra_months} month(s)"
        elif years:
            time_text = f"{years} year(s)"
        else:
            time_text = f"{months_needed} month(s)"

        total_contributed = months_needed * monthly
        final_balance = current + total_contributed

        return (
            "🎯 Savings Goal Calculator\n"
            f"- Current savings: ${current:,.2f}\n"
            f"- Target amount: ${target:,.2f}\n"
            f"- Amount still needed: ${remaining:,.2f}\n"
            f"- Monthly contribution: ${monthly:,.2f}\n"
            f"- Estimated time to goal: {time_text} ({months_needed} month(s))\n"
            f"- Estimated finish date: {target_date}\n"
            f"- Projected balance at that point: ${final_balance:,.2f}"
        )

    try:
        if hasattr(agent, "register_tool"):
            try:
                agent.register_tool(
                    name="savings_calculator",
                    description=(
                        "Calculate how long it will take to reach a savings target from current savings "
                        "and monthly contributions."
                    ),
                    function=savings_calculator
                )
            except TypeError:
                agent.register_tool(
                    "savings_calculator",
                    "Calculate how long it will take to reach a savings target.",
                    savings_calculator
                )

            print("✅ Savings calculator registered with the agent system.")

    except Exception as e:
        print(f"⚠️ Tool registration skipped: {e}")

    agent.savings_calculator = savings_calculator
    return savings_calculator

# Register and test your tool
savings_tool = create_savings_calculator_tool()
print(savings_tool(1000, 300, 10000))
# Out:
# ✅ Savings calculator registered with the agent system.
# 🎯 Savings Goal Calculator
# - Current savings: $1,000.00
# - Target amount: $10,000.00
# - Amount still needed: $9,000.00
# - Monthly contribution: $300.00
# - Estimated time to goal: 2 year(s) and 6 month(s) (30 month(s))
# - Estimated finish date: November 2028
# - Projected balance at that point: $10,000.00

# %% [markdown]
# ## Gradio UI Integration

# %%
# 🤖 AI Collaboration: Professional UI Design
# Ask AI to help you create a comprehensive Gradio interface

import gradio as gr

def create_finance_assistant_ui():
    """
    Create a comprehensive Gradio interface for the Smart Finance Assistant

    🤖 AI Collaboration Prompt:
    "Help me design a Gradio interface that combines CSV upload, spending
    analysis, chat functionality, and custom tools in a user-friendly
    layout suitable for a personal finance application."
    """
    import pandas as pd

    finance_bot = create_finance_chat_personality()
    savings_tool = create_savings_calculator_tool()
    rag_state = {"config": None}

    def run_transaction_analysis(uploaded_file):
        if uploaded_file is None:
            return (
                pd.DataFrame(),
                pd.DataFrame(),
                "⚠️ Please upload a transaction CSV file first.",
                ""
            )

        try:
            file_source = uploaded_file.name if hasattr(uploaded_file, "name") else uploaded_file

            cleaned_df = load_and_clean_transaction_data(file_source)
            analysis_result = analyze_spending_patterns(cleaned_df)
            recommendation_report = generate_financial_recommendations(analysis_result)

            display_df = cleaned_df.copy()
            display_df["Date"] = display_df["Date"].dt.strftime("%Y-%m-%d")

            summary_markdown = (
                "## 📊 Spending Summary\n"
                f"- **Transactions analysed:** {analysis_result['transaction_count']}\n"
                f"- **Total spending:** ${analysis_result['total_spending']:,.2f}\n"
                f"- **Refunds:** ${analysis_result['total_refunds']:,.2f}\n"
                f"- **Net cash impact:** ${analysis_result['net_spending']:,.2f}\n"
                f"- **Top category:** {analysis_result['top_category']}\n\n"
                + recommendation_report
            )

            chat_context = (
                f"Total spending ${analysis_result['total_spending']:,.2f}; "
                f"top category {analysis_result['top_category']} at "
                f"${analysis_result['top_category_amount']:,.2f}; "
                f"refunds ${analysis_result['total_refunds']:,.2f}. "
                f"Insights: {' '.join(analysis_result['business_insights'])}"
            )

            return display_df, analysis_result["category_summary"], summary_markdown, chat_context

        except Exception as e:
            return (
                pd.DataFrame(),
                pd.DataFrame(),
                f"⚠️ Could not analyse this file: {e}",
                ""
            )

    def ask_budget_buddy(message, analysis_context):
        if message is None or not str(message).strip():
            return "Please enter a finance or budgeting question."

        return finance_bot(str(message), analysis_summary=analysis_context)

    def ask_financial_documents(question):
        if question is None or not str(question).strip():
            return "Please enter a question about budgeting or spending."

        if rag_state["config"] is None:
            rag_state["config"] = setup_financial_rag()

        return rag_state["config"]["ask"](question)

    def calculate_savings_goal(current_savings, monthly_contribution, target_amount):
        return savings_tool(current_savings, monthly_contribution, target_amount)

    with gr.Blocks(title="Budget Buddy Smart Finance Assistant", theme=gr.themes.Soft()) as demo:
        analysis_context_state = gr.State("")

        gr.Markdown(
            """
# 🏦 Budget Buddy Smart Finance Assistant

Upload a transaction CSV, review your spending patterns, ask budget questions, search finance guidance, and calculate savings goals.
"""
        )

        with gr.Tab("📊 CSV Spending Analysis"):
            file_input = gr.File(label="Upload transactions CSV", file_types=[".csv"])
            analyse_button = gr.Button("Analyse Transactions", variant="primary")

            with gr.Row():
                cleaned_table = gr.Dataframe(label="Cleaned transactions", interactive=False)
                category_table = gr.Dataframe(label="Category spending summary", interactive=False)

            recommendations_output = gr.Markdown(label="Recommendations")

            analyse_button.click(
                fn=run_transaction_analysis,
                inputs=[file_input],
                outputs=[
                    cleaned_table,
                    category_table,
                    recommendations_output,
                    analysis_context_state
                ]
            )

        with gr.Tab("💬 Finance Chat"):
            gr.Markdown(
                "Ask Budget Buddy for practical, student-friendly budgeting advice. "
                "Upload and analyse a CSV first for personalised context."
            )

            chat_question = gr.Textbox(
                label="Your question",
                placeholder="Example: How can I cut my coffee spending?"
            )
            chat_button = gr.Button("Ask Budget Buddy")
            chat_answer = gr.Markdown(label="Budget Buddy response")

            chat_button.click(
                fn=ask_budget_buddy,
                inputs=[chat_question, analysis_context_state],
                outputs=[chat_answer]
            )

        with gr.Tab("🔍 Financial Document Search"):
            gr.Markdown(
                "Ask questions against the built-in budgeting guides and transaction summary documents."
            )

            rag_question = gr.Textbox(
                label="Document question",
                placeholder="Example: What is a good strategy for entertainment spending?"
            )
            rag_button = gr.Button("Search Finance Knowledge Base")
            rag_answer = gr.Markdown(label="Retrieved answer")

            rag_button.click(
                fn=ask_financial_documents,
                inputs=[rag_question],
                outputs=[rag_answer]
            )

        with gr.Tab("🎯 Savings Goal Calculator"):
            with gr.Row():
                current_input = gr.Number(label="Current savings ($)", value=0)
                monthly_input = gr.Number(label="Monthly contribution ($)", value=100)
                target_input = gr.Number(label="Target amount ($)", value=1000)

            savings_button = gr.Button("Calculate Savings Timeline")
            savings_output = gr.Textbox(label="Savings result", lines=9)

            savings_button.click(
                fn=calculate_savings_goal,
                inputs=[current_input, monthly_input, target_input],
                outputs=[savings_output]
            )

        with gr.Tab("ℹ️ About"):
            gr.Markdown(
                """
### What this app does
- Cleans real CSV transaction exports.
- Separates expenses, refunds and zero-value transactions.
- Calculates category totals and percentages.
- Generates practical budgeting recommendations.
- Adds AI chat, document retrieval and a custom savings calculator.

_This app provides budgeting education, not personal financial advice._
"""
            )

    return demo

# Launch your complete application
demo = create_finance_assistant_ui()
demo.launch()
# Out:
# ✅ Finance chatbot personality created. Use chat.say('your question') to test it.
# ✅ Savings calculator registered with the agent system.
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://54b28eb4e30266f990.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://54b28eb4e30266f990.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---
#
# # 🧪 STEP 6: Test with a Variety of Data
#
# **🔍 Comprehensive Testing Strategy**
#
# Create thorough tests for your Smart Finance Assistant to ensure it handles real-world scenarios.
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration for Testing
#
# **Effective Testing Prompts:**
# ```
# "Help me create comprehensive test cases for my finance assistant. Include:
# - Normal transaction data
# - Edge cases (refunds, large amounts, missing data)
# - Invalid data scenarios (corrupted files, wrong formats)
# - Business logic validation (spending calculations, recommendations)
# Create assert statements to verify each scenario."
# ```
# :::
#
# ## Foundation Function Tests

# %%
# 🤖 AI Collaboration: Comprehensive Test Suite
# Ask AI to help you create thorough test cases

def create_test_datasets():
    """
    Create various test datasets for comprehensive testing

    🤖 AI Collaboration Prompt:
    "Create realistic test datasets for a finance assistant including:
    1. Normal spending data with various categories
    2. Edge cases: refunds (negative amounts), missing data, zero amounts
    3. Data quality issues: invalid formats, extreme values
    4. Business scenarios: high spending months, savings patterns
    Include Australian business names and realistic amounts."
    """
    import pandas as pd

    datasets = {
        "normal": pd.DataFrame({
            "Date": ["2024-08-01", "2024-08-02", "2024-08-03", "2024-08-04"],
            "Amount": ["$45.50", "$12.00", "$89.95", "$6.50"],
            "Category": ["Groceries", "Transport", "Entertainment", "Coffee"],
            "Description": [
                "Woolworths weekly shop",
                "Opal Card top-up",
                "Event Cinemas",
                "Campus Cafe"
            ]
        }),
        "edge_cases": pd.DataFrame({
            "Date": ["2024-08-05", "2024-08-06", "2024-08-07", "2024-08-08"],
            "Amount": ["-$25.00", "$0.00", "$1,250.75", "$8.50"],
            "Category": ["Refund", None, "Rent", ""],
            "Description": ["Returned textbook", None, "Student accommodation", ""]
        }),
        "invalid_amount": pd.DataFrame({
            "Date": ["2024-08-09"],
            "Amount": ["not-a-dollar-amount"],
            "Category": ["Coffee"],
            "Description": ["Broken amount example"]
        }),
        "invalid_date": pd.DataFrame({
            "Date": ["32/99/2024"],
            "Amount": ["$10.00"],
            "Category": ["Coffee"],
            "Description": ["Broken date example"]
        }),
        "missing_columns": pd.DataFrame({
            "Date": ["2024-08-10"],
            "Amount": ["$10.00"],
            "Category": ["Coffee"]
        }),
        "business_high_spending": pd.DataFrame({
            "Date": [
                "2024-08-01",
                "2024-08-02",
                "2024-08-03",
                "2024-08-04",
                "2024-08-05"
            ],
            "Amount": ["$240.00", "$150.00", "$35.00", "$20.00", "-$15.00"],
            "Category": ["Entertainment", "Entertainment", "Groceries", "Coffee", "Refund"],
            "Description": [
                "Concert tickets",
                "Festival deposit",
                "Coles groceries",
                "Campus coffees",
                "Ticket refund"
            ]
        })
    }

    return datasets

def test_data_loading_function():
    """
    Test the data loading and cleaning functionality

    🤖 AI Collaboration Prompt:
    "Create assert statements to test my data loading function with:
    - Valid CSV data
    - CSV with dollar signs in amounts
    - Missing values and invalid data
    - Empty files and corrupted data
    Verify that cleaning works correctly and errors are handled gracefully."
    """
    import pandas as pd
    from io import StringIO

    print("🧪 Testing data loading function...")

    datasets = create_test_datasets()

    normal_cleaned = load_and_clean_transaction_data(datasets["normal"])

    assert len(normal_cleaned) == 4, "Valid dataset should keep all rows."
    assert pd.api.types.is_datetime64_any_dtype(
        normal_cleaned["Date"]
    ), "Date column should be converted to datetime."
    assert pd.api.types.is_numeric_dtype(
        normal_cleaned["Amount"]
    ), "Amount column should be converted to numeric."
    assert abs(normal_cleaned["Amount"].sum() - 153.95) < 0.01, (
        "Dollar signs should be removed and amounts summed correctly."
    )

    edge_cleaned = load_and_clean_transaction_data(datasets["edge_cases"])

    assert edge_cleaned.loc[edge_cleaned["Amount"] < 0, "Transaction_Type"].iloc[0] == "Refund", (
        "Negative amounts should be marked as refunds."
    )
    assert "Uncategorised" in edge_cleaned["Category"].values, (
        "Missing or blank categories should be filled."
    )
    assert "No description provided" in edge_cleaned["Description"].values, (
        "Missing or blank descriptions should be filled."
    )
    assert edge_cleaned["Amount"].max() == 1250.75, (
        "Comma-separated amounts should be handled."
    )

    csv_text = (
        "Date,Amount,Category,Description\n"
        "2024-08-01,$10.00,Coffee,Campus Cafe\n"
        "2024-08-02,-$5.00,Refund,Returned item\n"
    )

    csv_cleaned = load_and_clean_transaction_data(StringIO(csv_text))

    assert csv_cleaned.shape[0] == 2, "CSV file-like objects should load correctly."
    assert csv_cleaned["Amount"].tolist() == [10.0, -5.0], (
        "Positive and negative CSV amounts should be parsed correctly."
    )

    try:
        load_and_clean_transaction_data(datasets["invalid_amount"])
        assert False, "Invalid amount data should raise a ValueError."
    except ValueError as e:
        assert "amount" in str(e).lower(), (
            "Invalid amount error should be user-friendly and mention amounts."
        )

    try:
        load_and_clean_transaction_data(datasets["invalid_date"])
        assert False, "Invalid date data should raise a ValueError."
    except ValueError as e:
        assert "date" in str(e).lower(), (
            "Invalid date error should be user-friendly and mention dates."
        )

    try:
        load_and_clean_transaction_data(datasets["missing_columns"])
        assert False, "Missing required columns should raise a ValueError."
    except ValueError as e:
        assert "missing" in str(e).lower() and "description" in str(e).lower(), (
            "Missing column error should identify the missing column."
        )

    try:
        load_and_clean_transaction_data(StringIO(""))
        assert False, "Empty CSV files should raise a ValueError."
    except ValueError as e:
        assert "empty" in str(e).lower(), (
            "Empty file error should explain the problem."
        )

    print("✅ Data loading tests passed.")

def test_spending_analysis():
    """
    Test spending analysis calculations

    🤖 AI Collaboration Prompt:
    "Create tests for spending analysis that verify:
    - Category totals are calculated correctly
    - Percentages add up to 100%
    - Refunds are handled appropriately
    - Edge cases like single transactions or empty categories
    Use assert statements with known expected results."
    """
    import pandas as pd

    print("🧪 Testing spending analysis...")

    known_data = pd.DataFrame({
        "Date": [
            "2024-08-01",
            "2024-08-02",
            "2024-08-03",
            "2024-08-04",
            "2024-08-05"
        ],
        "Amount": ["$10.00", "$20.00", "-$5.00", "$0.00", "$30.00"],
        "Category": ["Coffee", "Transport", "Refund", "Coffee", "Groceries"],
        "Description": ["Cafe", "Bus pass", "Returned item", "Free sample", "Coles"]
    })

    cleaned = load_and_clean_transaction_data(known_data)
    result = analyze_spending_patterns(cleaned)

    assert result["total_spending"] == 60.0, (
        "Total spending should include positive expenses only."
    )
    assert result["total_refunds"] == 5.0, (
        "Refunds should be tracked separately as positive refund totals."
    )
    assert result["net_spending"] == 55.0, (
        "Net spending should include refunds."
    )
    assert result["category_totals"]["Groceries"] == 30.0, (
        "Groceries total should be calculated correctly."
    )
    assert result["category_totals"]["Transport"] == 20.0, (
        "Transport total should be calculated correctly."
    )
    assert result["category_totals"]["Coffee"] == 10.0, (
        "Coffee total should exclude zero-value transactions from spending."
    )
    assert abs(result["category_summary"]["Percentage"].sum() - 100.0) < 0.05, (
        "Category percentages should add up to 100%."
    )
    assert result["top_category"] == "Groceries", (
        "Top category should be the highest positive spending category."
    )
    assert result["refund_transaction_count"] == 1, (
        "Refund transaction count should be correct."
    )

    single_transaction = load_and_clean_transaction_data(pd.DataFrame({
        "Date": ["2024-08-10"],
        "Amount": ["$42.00"],
        "Category": ["Dining"],
        "Description": ["Guzman y Gomez"]
    }))

    single_result = analyze_spending_patterns(single_transaction)

    assert single_result["total_spending"] == 42.0, (
        "Single transaction total should be correct."
    )
    assert single_result["top_category"] == "Dining", (
        "Single transaction category should become top category."
    )
    assert single_result["category_summary"]["Percentage"].iloc[0] == 100.0, (
        "Single category should represent 100%."
    )

    try:
        analyze_spending_patterns(pd.DataFrame())
        assert False, "Empty analysis input should raise a ValueError."
    except ValueError as e:
        assert "no transactions" in str(e).lower() or "missing" in str(e).lower(), (
            "Empty data error should be clear."
        )

    print("✅ Spending analysis tests passed.")

def test_business_insights():
    """
    Test business recommendation generation

    🤖 AI Collaboration Prompt:
    "Create tests that verify business insights are appropriate:
    - High spending categories are identified correctly
    - Savings opportunities are realistic
    - Recommendations match spending patterns
    - Output format is user-friendly"
    """
    print("🧪 Testing business insights...")

    datasets = create_test_datasets()

    cleaned = load_and_clean_transaction_data(datasets["business_high_spending"])
    result = analyze_spending_patterns(cleaned)
    report = generate_financial_recommendations(result)

    assert isinstance(report, str) and len(report) > 300, (
        "Recommendation report should be a substantial formatted string."
    )
    assert "Budget Buddy" in report, (
        "Report should be clearly branded for the app user."
    )
    assert "Entertainment" in report, (
        "Report should mention the highest spending category."
    )
    assert "$390.00" in report, (
        "Report should include the correct high category amount."
    )
    assert "10%" in report or "5-10%" in report, (
        "Report should include a realistic savings opportunity."
    )
    assert "Action plan" in report, (
        "Report should include an action-focused section."
    )
    assert "not personal financial advice" in report.lower(), (
        "Report should include an appropriate educational disclaimer."
    )

    empty_style_analysis = {
        "total_spending": 0,
        "total_refunds": 25,
        "net_spending": -25,
        "date_range": {"start": "2024-08-01", "end": "2024-08-01"},
        "category_summary": [],
        "business_insights": []
    }

    empty_report = generate_financial_recommendations(empty_style_analysis)

    assert "No positive spending" in empty_report, (
        "No-spending scenarios should be handled gracefully."
    )

    print("✅ Business insight tests passed.")

# Run all tests
print("🔍 COMPREHENSIVE TESTING SUITE")
print("=" * 40)

try:
    create_test_datasets()
    test_data_loading_function()
    test_spending_analysis()
    test_business_insights()
    print("✅ All tests passed! Your finance assistant is working correctly.")
except AssertionError as e:
    print(f"❌ Test failed: {e}")
except Exception as e:
    print(f"⚠️ Test error: {e}")
# Out:
# 🔍 COMPREHENSIVE TESTING SUITE
# ...
# 🧪 Testing data loading function...
# ✅ Data loading tests passed.
# 🧪 Testing spending analysis...
# ✅ Spending analysis tests passed.
# 🧪 Testing business insights...
# ✅ Business insight tests passed.
# ✅ All tests passed! Your finance assistant is working correctly.

# %% [markdown]
# ## Advanced Integration Tests

# %%
# 🤖 AI Collaboration: Integration Testing
# Ask AI to help test the complete system integration

def test_full_workflow():
    """
    Test the complete workflow from CSV upload to final recommendations

    🤖 AI Collaboration Prompt:
    "Create an end-to-end test that:
    1. Loads sample CSV data
    2. Runs complete analysis pipeline
    3. Generates chat responses about the data
    4. Verifies RAG system retrieval
    5. Tests custom tool functionality
    Ensure all components work together seamlessly."
    """
    import os

    print("🧪 Testing complete workflow integration...")

    sample_path = "sample_transactions.csv"

    if not os.path.exists(sample_path):
        sample_path = "/mnt/data/sample_transactions.csv"

    if os.path.exists(sample_path):
        cleaned = load_and_clean_transaction_data(sample_path)
    else:
        cleaned = load_and_clean_transaction_data(create_test_datasets()["normal"])

    analysis_result = analyze_spending_patterns(cleaned)
    recommendations = generate_financial_recommendations(analysis_result)

    assert not cleaned.empty, "Full workflow should load transaction data."
    assert analysis_result["total_spending"] > 0, (
        "Full workflow should calculate positive spending."
    )
    assert isinstance(recommendations, str) and "Budget Buddy" in recommendations, (
        "Full workflow should generate a formatted recommendation report."
    )

    had_get_response = hasattr(chat, "get_response")
    original_get_response = getattr(chat, "get_response", None)

    try:
        chat.get_response = lambda prompt, system=None, **kwargs: (
            "Mock chat response: reduce the highest flexible category first."
        )

        finance_bot = create_finance_chat_personality()

        chat_response = finance_bot(
            "What should I improve first?",
            analysis_summary=(
                f"Top category: {analysis_result['top_category']}; "
                f"total spending: ${analysis_result['total_spending']:,.2f}"
            )
        )

        assert "Mock chat response" in chat_response, (
            "Chatbot should return a response when the AI service is available."
        )

    finally:
        if had_get_response:
            chat.get_response = original_get_response
        elif hasattr(chat, "get_response"):
            delattr(chat, "get_response")

    rag_config = setup_financial_rag()

    assert callable(rag_config["ask"]), (
        "RAG setup should return a callable ask function."
    )

    rag_answer = rag_config["ask"](
        "What is a good budgeting strategy for entertainment?"
    )

    assert isinstance(rag_answer, str) and len(rag_answer) > 20, (
        "RAG retrieval should return a useful answer."
    )

    savings_tool = create_savings_calculator_tool()
    savings_result = savings_tool(100, 50, 300)

    assert "4 month" in savings_result, (
        "Savings calculator should calculate the expected timeline."
    )
    assert "$300.00" in savings_result, (
        "Savings calculator should include the target amount."
    )

    print("✅ Full workflow integration test passed.")

def test_error_handling():
    """
    Test error handling and user experience

    🤖 AI Collaboration Prompt:
    "Create tests that verify error handling for:
    - Invalid file uploads
    - Network connection issues
    - Malformed data
    - User input validation
    Ensure error messages are user-friendly and helpful."
    """
    import pandas as pd
    from io import StringIO

    print("🧪 Testing error handling...")

    try:
        load_and_clean_transaction_data("file_that_does_not_exist.csv")
        assert False, "Invalid file paths should raise a clear ValueError."
    except ValueError as e:
        assert "could not be found" in str(e).lower() or "unable to load" in str(e).lower(), (
            "Invalid file upload error should be clear."
        )

    malformed_csv = StringIO(
        "Date,Amount,Category,Description\n"
        "2024-08-01,abc,Coffee,Cafe\n"
    )

    try:
        load_and_clean_transaction_data(malformed_csv)
        assert False, "Malformed amount data should raise a ValueError."
    except ValueError as e:
        assert "amount" in str(e).lower(), (
            "Malformed data error should mention the amount problem."
        )

    missing_columns_csv = StringIO(
        "Date,Amount,Category\n"
        "2024-08-01,$10.00,Coffee\n"
    )

    try:
        load_and_clean_transaction_data(missing_columns_csv)
        assert False, "CSV files with missing columns should raise a ValueError."
    except ValueError as e:
        assert "missing" in str(e).lower(), (
            "Missing column error should use helpful wording."
        )

    had_get_response = hasattr(chat, "get_response")
    original_get_response = getattr(chat, "get_response", None)

    try:
        chat.get_response = lambda *args, **kwargs: (
            _ for _ in ()
        ).throw(RuntimeError("Simulated network failure"))

        finance_bot = create_finance_chat_personality()
        response = finance_bot("How do I reduce coffee spending?")

        assert "trouble connecting" in response.lower(), (
            "Chatbot should provide a friendly fallback when the AI service fails."
        )

    finally:
        if had_get_response:
            chat.get_response = original_get_response
        elif hasattr(chat, "get_response"):
            delattr(chat, "get_response")

    savings_tool = create_savings_calculator_tool()

    assert "valid number" in savings_tool("abc", 50, 500).lower(), (
        "Savings tool should validate numeric inputs."
    )
    assert "greater than $0" in savings_tool(100, 0, 500), (
        "Savings tool should explain that monthly contribution must be positive."
    )
    assert "already reached" in savings_tool(600, 50, 500).lower(), (
        "Savings tool should handle already-achieved goals."
    )

    try:
        analyze_spending_patterns(
            pd.DataFrame({
                "Date": ["2024-08-01"],
                "Amount": ["$10.00"]
            })
        )
        assert False, "Analysis should reject data missing Category and Description."
    except ValueError as e:
        assert "missing" in str(e).lower(), (
            "Analysis missing column error should be clear."
        )

    print("✅ Error handling tests passed.")

# Run integration tests
try:
    test_full_workflow()
    test_error_handling()
    print("✅ Integration tests completed successfully!")
except Exception as e:
    print(f"⚠️ Integration test issue: {e}")
# Out:
# 🧪 Testing complete workflow integration...
# ✅ Finance chatbot personality created. Use chat.say('your question') to test it.
# ✅ Financial document retrieval is ready using keyword search mode.
# ✅ Savings calculator registered with the agent system.
# ✅ Full workflow integration test passed.
# 🧪 Testing error handling...
# ✅ Finance chatbot personality created. Use chat.say('your question') to test it.
# ✅ Savings calculator registered with the agent system.
# ✅ Error handling tests passed.
# ✅ Integration tests completed successfully!

# %% [markdown]
# ---
#
# # 📊 Project Completion Checklist
#
# ## Foundation Skills ✅
# - [ ] **Data Processing**: CSV loading and cleaning functions work reliably
# - [ ] **Analysis Functions**: Spending summaries calculate correctly
# - [ ] **Business Insights**: Recommendations are relevant and actionable
# - [ ] **Error Handling**: Graceful handling of data issues
# - [ ] **Testing**: Comprehensive test coverage for core functions
# - [ ] **Documentation**: Clear AI collaboration documentation in diary
#
# ## Advanced Integration ✅
# - [ ] **Chat Interface**: Finance advisor personality implemented
# - [ ] **RAG System**: Document retrieval for financial guidance
# - [ ] **Custom Tools**: At least one financial calculator/utility
# - [ ] **Gradio UI**: Professional, user-friendly interface
# - [ ] **Full Integration**: All components work together seamlessly
#
# ## Professional Standards ✅
# - [ ] **Code Quality**: Professional, commented, maintainable code
# - [ ] **Business Focus**: Clear connection to real finance problems
# - [ ] **User Experience**: Interface suitable for non-technical users
# - [ ] **AI Collaboration**: Extensive, well-documented AI usage
# - [ ] **Testing**: Robust validation of all features
#
# ## Project Documentation ✅
# - [ ] **Developer's Diary**: Complete AI collaboration documentation
# - [ ] **README**: Clear project description and usage instructions
# - [ ] **GitHub**: Regular commits showing development progress
# - [ ] **Reflection**: Thoughtful analysis of learning and challenges
#
# ---
#
# # 🎯 Final Thoughts: Your Finance Assistant Journey
#
# Congratulations on building your Smart Finance Assistant! This project represents a significant achievement in modern business programming:
#
# **Technical Skills Developed:**
# - AI-assisted development workflows
# - Professional data processing with pandas
# - Integration of multiple AI technologies
# - User interface design with Gradio
# - Comprehensive software testing
#
# **Business Skills Developed:**
# - Financial data analysis and insights
# - User-centered application design
# - Professional documentation practices
# - Iterative development methodology
# - Critical evaluation of AI suggestions
#
# **Professional Preparation:**
# - Experience with industry-standard AI collaboration
# - Portfolio-ready application development
# - Understanding of business problem-solving with technology
# - Documentation practices for workplace environments
#
# **Your Smart Finance Assistant demonstrates your ability to direct AI tools toward meaningful business solutions - exactly the skill set that modern BIS graduates need for career success!**
#
# ---
#
# *Remember to document all AI collaborations in your Developer's Diary and maintain regular GitHub commits throughout your development process.*
